# %%
# !pip install -U datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
cd /content/drive/MyDrive/Phd/IT7361/Code

# %%
from datasets import load_dataset
dataset = load_dataset("Fsoft-AIC/the-vault-function", split_set=["train/small", "test"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# the-vault-function.py: 0.00B [00:00, ?B/s]
# python-00000-of-00002.parquet:   0%|          | 0.00/278M [00:00<?, ?B/s]
# python-00001-of-00002.parquet:   0%|          | 0.00/276M [00:00<?, ?B/s]
# c-00000-of-00001.parquet:   0%|          | 0.00/153M [00:00<?, ?B/s]
# c_sharp-00000-of-00001.parquet:   0%|          | 0.00/137M [00:00<?, ?B/s]
# cpp-00000-of-00001.parquet:   0%|          | 0.00/105M [00:00<?, ?B/s]
# ...

# %%
print(dataset)
# Out:
# DatasetDict({
#     train_small: Dataset({
#         features: ['hexsha', 'repo', 'path', 'license', 'language', 'identifier', 'return_type', 'original_string', 'original_docstring', 'docstring', 'docstring_tokens', 'code', 'code_tokens', 'short_docstring', 'short_docstring_tokens', 'comment', 'parameters', 'docstring_params'],
#         num_rows: 1702750
#     })
#     test: Dataset({
#         features: ['hexsha', 'repo', 'path', 'license', 'language', 'identifier', 'return_type', 'original_string', 'original_docstring', 'docstring', 'docstring_tokens', 'code', 'code_tokens', 'short_docstring', 'short_docstring_tokens', 'comment', 'parameters', 'docstring_params'],
#         num_rows: 202614
#     })
# })

# %%
clean_data = dataset.filter(lambda example: (2048 > len(example["short_docstring"]) > 30) and (300 > len(example["code"].splitlines()) > 3), num_proc=10)
# Out:
# ...
# Filter (num_proc=10):   0%|          | 0/202614 [00:00<?, ? examples/s]

# %%
clean_data = dataset.filter(lambda example: (2048 > len(example["short_docstring"]) > 30) and (300 > len(example["code"].splitlines()) > 3), num_proc=10)

# %%
print(clean_data)
# Out:
# DatasetDict({
#     train_small: Dataset({
#         features: ['hexsha', 'repo', 'path', 'license', 'language', 'identifier', 'return_type', 'original_string', 'original_docstring', 'docstring', 'docstring_tokens', 'code', 'code_tokens', 'short_docstring', 'short_docstring_tokens', 'comment', 'parameters', 'docstring_params'],
#         num_rows: 1523862
#     })
#     test: Dataset({
#         features: ['hexsha', 'repo', 'path', 'license', 'language', 'identifier', 'return_type', 'original_string', 'original_docstring', 'docstring', 'docstring_tokens', 'code', 'code_tokens', 'short_docstring', 'short_docstring_tokens', 'comment', 'parameters', 'docstring_params'],
#         num_rows: 183448
#     })
# })

# %%
languages = set(clean_data["test"]["language"])
for lang in languages:
  lang_data = clean_data.filter(lambda example: example["language"] == lang, num_proc=1)
  lang_data.save_to_disk(f"data/{lang}.hf")

# %%
for lang in languages:
  lang_data = clean_data.filter(lambda example: example["language"] == lang, num_proc=1)
  lang_data.save_to_disk(f"data/{lang}.hf")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/14289 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk
data = {}
for lang in languages:
  data[lang] = load_from_disk(f"data/{lang}.hf")

# %%
print(data["Go"]["train_small"][0]["docstring"])
# Out:
# NewClient creates the Cient with configuration.

# %%
import numpy as np
a = [24.56, 29.81, 24.52, 32.08]
print(np.mean(a), np.std(a))
# Out:
# 27.7425 3.301563076786509

# %% [markdown]
# # DSI

# %%
# !pip install transformers datasets==2.10.1 fsspec==2023.6.0 jsonlines

# %%
cd /content/drive/MyDrive/Phd/IT7361/Code/DSI
# Out:
# /content/drive/MyDrive/Phd/IT7361/Code/DSI

# %%
# !pip install --upgrade transformers
# Out:
# ...
#   Using cached transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
# ...
# Using cached transformers-4.53.2-py3-none-any.whl (10.8 MB)
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.17.0
#     Uninstalling transformers-4.17.0:
#       Successfully uninstalled transformers-4.17.0
# ...

# %%
# !bash scripts/train.sh
# Out:
# 2025-07-16 15:06:23.646206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752678383.668612   28038 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752678383.675788   28038 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 15:06:23.696277: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
